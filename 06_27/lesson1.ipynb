# %%
#1) list：要自己一個個處理。list 適合一般資料儲存。

a = [1, 2, 3]
print(a + [4, 5, 6])  #[1, 2, 3, 4, 5, 6]
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
#2) numpy：可以直接整個做運算。numpy 適合數值運算，寫法更簡潔，也通常更快。

import numpy as np

b = np.array([1, 2, 3])
print(b + np.array([4, 5, 6]))  #[5 7 9]
# Out:
# [5 7 9]
