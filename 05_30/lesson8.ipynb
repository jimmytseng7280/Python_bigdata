# %%
#class list:

class list:
    def __init__(self, name):
        self.name = name
    def __str__(self):
        return self.name
a = list("hello")
print(a)
# Out:
# hello

# %%
students = [68, 95, 78, 65, 92]
