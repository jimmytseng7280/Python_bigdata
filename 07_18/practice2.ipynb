# %%
import numpy as np
import pandas as pd

data = pd.Series(np.random.randn(9),
                index=[['a', 'a', 'a', 'b', 'b', 'c', 'c', 'd', 'd'],
                       [1, 2, 3, 1, 2, 3, 1, 2, 3]])
data
# Out:
# a  1    0.822313
#    2    0.177626
#    3    0.615461
# b  1    0.429296
#    2    1.230584
# c  3   -0.262282
#    1   -0.502685
# d  2   -0.377613
#    3   -1.623414
# dtype: float64

# %%
data1 = data.unstack()
data1
# Out:
#           1         2         3
# a  0.822313  0.177626  0.615461
# b  0.429296  1.230584       NaN
# c -0.502685       NaN -0.262282
# d       NaN -0.377613 -1.623414

# %%
data1.stack()
# Out:
# a  1    0.822313
#    2    0.177626
#    3    0.615461
# b  1    0.429296
#    2    1.230584
#    3         NaN
# c  1   -0.502685
#    2         NaN
#    3   -0.262282
# d  1         NaN
#    2   -0.377613
#    3   -1.623414
# dtype: float64
