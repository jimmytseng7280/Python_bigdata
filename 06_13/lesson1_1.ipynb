# %%
import requests
from requests import Response
from pandas import DataFrame
import pandas as pd

# 台北市 YouBike 2.0 的 Web API 網址
url:str = "https://tcgbusfs.blob.core.windows.net/dotapp/youbike/v2/youbike_immediate.json"

    # 使用 requests 套件裡面的 get 函式，執行後會傳出 Response 的實體
response:Response = requests.get(url) 

if response.status_code == 200: # 使用 Response 裡的 Property 叫 status_code，如果取得的數字是 200 代表下載成功，如果不是則代表下載失敗
		data:list[dict] = response.json() # 使用 Response 實體的 json() 方法，會傳出 list 的資料結構

		# list[dict] -> DataFrame
		df:DataFrame = pd.DataFrame(data=data)
df
# Out:
#             sno                      sna   sarea                 mday  \
# 0     500101001       YouBike2.0_捷運科技大樓站     大安區  2026-06-13 13:27:04
# 1     500101002   YouBike2.0_復興南路二段273號前     大安區  2026-06-13 13:28:03
# 2     500101003     YouBike2.0_國北教大實小東側門     大安區  2026-06-13 13:28:03
# 3     500101004        YouBike2.0_和平公園東側     大安區  2026-06-13 13:27:04
# 4     500101005     YouBike2.0_辛亥復興路口西北側     大安區  2026-06-13 13:28:03
# ...         ...                      ...     ...                  ...
# 1759  500119094     YouBike2.0_臺大大一女餐廳廣場  臺大公館校區  2026-06-13 13:26:03
# 1760  500119095         YouBike2.0_臺大學新館  臺大公館校區  2026-06-13 13:28:03
# 1761  500119096      YouBike2.0_臺大水源舍區C棟  臺大公館校區  2026-06-13 13:23:04
# 1762  500119097         YouBike2.0_臺大人文館  臺大公館校區  2026-06-13 13:27:04
# 1763  500119098  YouBike2.0_臺大數學研究中心(東側)  臺大公館校區  2026-06-13 13:27:04
#
#                  ar     sareaen  \
# 0       復興南路二段235號前  Daan Dist.
# 1      復興南路二段273號西側  Daan Dist.
# 2       和平東路二段96巷7號  Daan Dist.
# 3     和平東路二段118巷33號  Daan Dist.
# 4        復興南路二段368號  Daan Dist.
# ...             ...         ...
# 1759    臺大大一女餐廳廣場後方    NTU Dist
# 1760         臺大學新館旁    NTU Dist
# 1761     臺大水源舍區C棟西側    NTU Dist
# 1762       臺大人文館東北側    NTU Dist
# 1763     臺大數學研究中心東側    NTU Dist
#
#                                                   snaen  \
# 0                  YouBike2.0_MRT Technology Bldg. Sta.
# 1              YouBike2.0_No.273， Sec. 2， Fuxing S. Rd.
# 2     YouBike2.0_NTUE Experiment Elementary School (...
# 3                         YouBike2.0_Heping Park (East)
# 4     YouBike2.0_Xinhai Fuxing Rd. Intersection (Nor...
# ...                                                 ...
# 1759    YouBike2.0_NTU Freshman Women's Dorm Restaurant
# 1760                  YouBike2.0_NTU MK Innovation Hall
# 1761                   YouBike2.0_NTU Shui-Yuan Dorms C
# 1762         YouBike2.0_NTU The College of Liberal Arts
# 1763  YouBike2.0_Mathematics National Taiwan Univers...
#
#                                                aren act        srcUpdateTime  \
# 0                     No.235， Sec. 2， Fuxing S. Rd.   1  2026-06-13 13:28:52
# 1              No.273， Sec. 2， Fuxing S. Rd. (West)   1  2026-06-13 13:28:52
# 2               No. 7， Ln. 96， Sec. 2， Heping E. Rd   1  2026-06-13 13:28:52
# 3             No. 33， Ln. 118， Sec. 2， Heping E. Rd   1  2026-06-13 13:28:52
# 4                    No. 368， Sec. 2， Fuxing S. Rd.   1  2026-06-13 13:28:52
# ...                                             ...  ..                  ...
# 1759           NTU Freshman Women's Dorm Restaurant   1  2026-06-13 13:28:52
# 1760                         NTU MK Innovation Hall   1  2026-06-13 13:28:52
# 1761                   NTU Shui-Yuan Dorms C (West)   1  2026-06-13 13:28:52
# 1762    NTU The College of Liberal Arts (Northeast)   1  2026-06-13 13:28:52
# 1763  Mathematics National Taiwan University (East)   1  2026-06-13 13:28:52
#
#                updateTime             infoTime    infoDate  Quantity  \
# 0     2026-06-13 13:28:52  2026-06-13 13:27:04  2026-06-13        28
# 1     2026-06-13 13:28:52  2026-06-13 13:28:03  2026-06-13        21
# 2     2026-06-13 13:28:52  2026-06-13 13:28:03  2026-06-13        28
# 3     2026-06-13 13:28:52  2026-06-13 13:27:04  2026-06-13        11
# 4     2026-06-13 13:28:52  2026-06-13 13:28:03  2026-06-13        16
# ...                   ...                  ...         ...       ...
# 1759  2026-06-13 13:28:52  2026-06-13 13:26:03  2026-06-13        40
# 1760  2026-06-13 13:28:52  2026-06-13 13:28:03  2026-06-13        33
# 1761  2026-06-13 13:28:52  2026-06-13 13:23:04  2026-06-13        99
# 1762  2026-06-13 13:28:52  2026-06-13 13:27:04  2026-06-13        67
# 1763  2026-06-13 13:28:52  2026-06-13 13:27:04  2026-06-13        62
#
#       available_rent_bikes  latitude  longitude  available_return_bikes
# 0                       10  25.02605  121.54360                      18
# 1                       17  25.02565  121.54357                       4
# 2                        2  25.02429  121.54124                      25
# 3                        8  25.02351  121.54282                       3
# 4                        5  25.02153  121.54299                      11
# ...                    ...       ...        ...                     ...
# 1759                    28  25.01479  121.53494                       3
# 1760                     8  25.01944  121.54339                      24
# 1761                    19  25.01547  121.52892                      80
# 1762                    59  25.01820  121.53476                       8
# 1763                    10  25.02004  121.53881                      52
#
# [1764 rows x 18 columns]

# %%
df.iloc[0]
# Out:
# sno                                                  500101001
# sna                                         YouBike2.0_捷運科技大樓站
# sarea                                                      大安區
# mday                                       2026-06-13 10:21:03
# ar                                                 復興南路二段235號前
# sareaen                                             Daan Dist.
# snaen                     YouBike2.0_MRT Technology Bldg. Sta.
# aren                             No.235， Sec. 2， Fuxing S. Rd.
# act                                                          1
# srcUpdateTime                              2026-06-13 10:21:52
# updateTime                                 2026-06-13 10:21:52
# infoTime                                   2026-06-13 10:21:03
# infoDate                                            2026-06-13
# Quantity                                                    28
# available_rent_bikes                                         2
# latitude                                              25.02605
# longitude                                             121.5436
# available_return_bikes                                      26
# Name: 0, dtype: object

# %%
from pathlib import Path
output_file = output_file = Path(__file__).with_name("youbike_report.pdf")
output_file
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 from pathlib import Path
# ----> 2 output_file = output_file = Path(__file__).with_name("youbike_report.pdf")
#       3 output_file
#
# NameError: name '__file__' is not defined

# %%
from pathlib import Path
output_file = Path.cwd().with_name("youbike_report.pdf")
output_file
# Out:
# WindowsPath('d:/AI/BigData/GitHub/Python_bigdata/youbike_report.pdf')
