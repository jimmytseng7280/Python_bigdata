# %%
print("Hello, Python!")
# Out:
# Hello, Python!

# %%
i=1

while i <= 7:
    print(i)
    i += 1
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7

# %%
i=1

while i <= 10:
    i += 1
    if i % 2 == 0:
        continue
    print(i)
# Out:
# 3
# 5
# 7
# 9
# 11

# %%
i = 0
while i < 10:
    i += 1
    if i == 3:
        continue
    if i == 8:
        break
    print(i)
# Out:
# 1
# 2
# 4
# 5
# 6
# 7
